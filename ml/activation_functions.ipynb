# %% [markdown]
# # 活性化関数
#
# ### 🔽 簡単なまとめ：ReLU / Sigmoid / Tanh の比較
#
# | 関数     | 出力範囲   | 中心が0 | 勾配消失のリスク | 主な用途                          |
# |----------|------------|---------|------------------|-----------------------------------|
# | ReLU     | 0 以上      | ✕       | 少ない           | 深層学習における標準的な隠れ層     |
# | Sigmoid  | 0 ～ 1      | ✕       | 起きやすい       | 出力層（バイナリ分類など）        |
# | Tanh     | -1 ～ 1     | ○       | 起こりうる       | RNNなどの中間層（古典的な用途）   |

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the activation functions
def relu(x):
    return np.maximum(0, x)

def sigmoid(x):
    return 1 / (1 + np.exp(-x))

def tanh(x):
    return np.tanh(x)

# Input range
x = np.linspace(-10, 10, 1000)

# Compute function values
y_relu = relu(x)
y_sigmoid = sigmoid(x)
y_tanh = tanh(x)

# Plotting
plt.figure(figsize=(12, 6))

# ReLU
plt.subplot(1, 3, 1)
plt.plot(x, y_relu, label="ReLU", color="blue")
plt.title("ReLU")
plt.grid(True)

# Sigmoid
plt.subplot(1, 3, 2)
plt.plot(x, y_sigmoid, label="Sigmoid", color="green")
plt.title("Sigmoid")
plt.grid(True)

# Tanh
plt.subplot(1, 3, 3)
plt.plot(x, y_tanh, label="Tanh", color="red")
plt.title("Tanh")
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 🔽 ざっくり比較表（ReLU以外の4つの重要な活性化関数）
#
# | 関数名     | 負の出力 | 勾配消失の回避 | 中心が0 | 特徴                                   |
# |------------|----------|------------------|---------|----------------------------------------|
# | Leaky ReLU | ○（小）  | ○                | ✕       | ReLUの死問題を軽減                     |
# | ELU        | ○        | ○                | ○       | 負の出力も自然、滑らかな曲線           |
# | Swish      | ○        | ◎                | ○       | Google提案、学習が安定、高性能な傾向   |
# | GELU       | ○        | ◎                | ○       | Transformer系で採用、統計的に洗練されている |

# %%
import numpy as np
import matplotlib.pyplot as plt

# 各種活性化関数の定義
def leaky_relu(x, alpha=0.01):
    return np.where(x > 0, x, alpha * x)

def elu(x, alpha=1.0):
    return np.where(x >= 0, x, alpha * (np.exp(x) - 1))

def swish(x):
    return x * (1 / (1 + np.exp(-x)))  # x * sigmoid(x)

def gelu(x):
    return 0.5 * x * (1 + np.tanh(np.sqrt(2 / np.pi) * (x + 0.044715 * x**3)))

# 入力の範囲
x = np.linspace(-10, 10, 1000)

# 関数ごとの出力を計算
y_leaky_relu = leaky_relu(x)
y_elu = elu(x)
y_swish = swish(x)
y_gelu = gelu(x)

# グラフの描画
fig, axes = plt.subplots(2, 2, figsize=(12, 8))

# Leaky ReLU
axes[0, 0].plot(x, y_leaky_relu, color="purple")
axes[0, 0].set_title("Leaky ReLU")
axes[0, 0].grid(True)

# ELU
axes[0, 1].plot(x, y_elu, color="orange")
axes[0, 1].set_title("ELU")
axes[0, 1].grid(True)

# Swish
axes[1, 0].plot(x, y_swish, color="green")
axes[1, 0].set_title("Swish")
axes[1, 0].grid(True)

# GELU
axes[1, 1].plot(x, y_gelu, color="blue")
axes[1, 1].set_title("GELU")
axes[1, 1].grid(True)

plt.tight_layout()
plt.show()
